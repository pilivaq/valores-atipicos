# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('MexicoCity_Sin_Nulos1.csv') 
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26067 entries, 0 to 26066
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0.1                                  26067 non-null  int64
#  1   Unnamed: 0                                    26067 non-null  int64
#  2   host_response_time                            26067 non-null  object
#  3   host_response_rate                            26067 non-null  int64
#  4   host_acceptance_rate                          26067 non-null  float64
#  5   host_is_superhost                             26067 non-null  object
#  6   host_location                                 26067 non-null  object
#  7   host_has_profile_pic                          26067 non-null  object
#  8   host_identity_verified                        26067 non-null  object
#  9   neighbourhood_cleansed                        26067 non-null  object
#  10  latitude                                      26067 non-null  float64
#  11  longitude                                     26067 non-null  float64
#  12  property_type                                 26067 non-null  object
#  13  room_type                                     26067 non-null  object
#  14  accommodates                                  26067 non-null  int64
#  15  bathrooms                                     26067 non-null  float64
#  16  bedrooms                                      26067 non-null  float64
#  17  beds                                          26067 non-null  float64
#  18  price                                         26067 non-null  float64
#  19  minimum_nights                                26067 non-null  int64
#  20  maximum_nights                                26067 non-null  int64
#  21  minimum_minimum_nights                        26067 non-null  int64
#  22  maximum_minimum_nights                        26067 non-null  int64
#  23  minimum_maximum_nights                        26067 non-null  int64
#  24  maximum_maximum_nights                        26067 non-null  int64
#  25  minimum_nights_avg_ntm                        26067 non-null  float64
#  26  maximum_nights_avg_ntm                        26067 non-null  float64
#  27  availability_30                               26067 non-null  int64
#  28  availability_60                               26067 non-null  int64
#  29  availability_90                               26067 non-null  int64
#  30  availability_365                              26067 non-null  int64
#  31  number_of_reviews                             26067 non-null  int64
#  32  number_of_reviews_ltm                         26067 non-null  int64
#  33  number_of_reviews_l30d                        26067 non-null  int64
#  34  number_of_reviews_ly                          26067 non-null  int64
#  35  estimated_occupancy_l365d                     26067 non-null  int64
#  36  estimated_revenue_l365d                       26067 non-null  float64
#  37  review_scores_rating                          26067 non-null  float64
#  38  review_scores_accuracy                        26067 non-null  float64
#  39  review_scores_cleanliness                     26067 non-null  float64
#  40  review_scores_checkin                         26067 non-null  float64
#  41  review_scores_communication                   26067 non-null  float64
#  42  review_scores_location                        26067 non-null  float64
#  43  review_scores_value                           26067 non-null  float64
#  44  calculated_host_listings_count                26067 non-null  int64
#  45  calculated_host_listings_count_entire_homes   26067 non-null  int64
#  46  calculated_host_listings_count_private_rooms  26067 non-null  int64
#  47  calculated_host_listings_count_shared_rooms   26067 non-null  int64
#  48  amenities                                     26067 non-null  object
#  49  has_availability                              26067 non-null  object
#  50  instant_bookable                              26067 non-null  object
# dtypes: float64(17), int64(23), object(11)
# memory usage: 10.1+ MB
# None

# %%
fig = plt.figure(figsize =(15, 8))
cuantitativas.plot(kind='box', vert=False)

plt.title("Valores Atípicos del Dataframe")
plt.show() 

cuantitativas['host_response_rate'].plot(kind='box', vert=False)
plt.show() 

cuantitativas['host_acceptance_rate'].plot(kind='box', vert=False)
plt.show() 

cuantitativas['latitude'].plot(kind='box', vert=False)
plt.show() 

cuantitativas['longitude'].plot(kind='box', vert=False)
plt.show() 

cuantitativas['accommodates'].plot(kind='box', vert=False)
plt.show() 

cuantitativas['bathrooms'].plot(kind='box', vert=False)
plt.show() 

cuantitativas['bedrooms'].plot(kind='box', vert=False)
plt.show() 

cuantitativas['beds'].plot(kind='box', vert=False)
plt.show() 

cuantitativas['price'].plot(kind='box', vert=False)
plt.show() 

cuantitativas[['minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights']].plot(kind='box', vert=False)
plt.show() 

cuantitativas[['minimum_nights_avg_ntm', 'maximum_nights_avg_ntm']].plot(kind='box', vert=False)
plt.show() 

cuantitativas[['availability_30', 'availability_60', 'availability_90', 'availability_365']].plot(kind='box', vert=False)
plt.show() 

cuantitativas[['number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d']].plot(kind='box', vert=False)
plt.show() 

cuantitativas[['estimated_occupancy_l365d', 'estimated_revenue_l365d']].plot(kind='box', vert=False)
plt.show() 

cuantitativas[['review_scores_rating', 'review_scores_accuracy', 'review_scores_communication', 'review_scores_location', 'review_scores_value']].plot(kind='box', vert=False)
plt.show() 

cuantitativas[['calculated_host_listings_count',  'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms']].plot(kind='box', vert=False)
plt.show()

# %% [markdown]
# Desviacion estandar

# %%
cuantitativas = data.iloc[:, [3, 4, 10, 11] + list(range(14, 47))]
cualitativas = data.iloc[:, [2, 3, 5, 6, 7, 8, 9, 12, 13, 48, 49, 50]]

# %%
y=cuantitativas
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido host_response_rate                              1.922927e+02
# host_acceptance_rate                            1.605067e+02
# latitude                                        1.953278e+01
# longitude                                      -9.906558e+01
# accommodates                                    1.042387e+01
# bathrooms                                       4.745669e+00
# bedrooms                                        5.401332e+00
# beds                                            6.762333e+00
# price                                           1.379969e+04
# minimum_nights                                  8.006843e+01
# maximum_nights                                  1.726096e+03
# minimum_minimum_nights                          7.764239e+01
# maximum_minimum_nights                          7.944952e+01
# minimum_maximum_nights                          3.998607e+07
# maximum_maximum_nights                          3.998610e+07
# minimum_nights_avg_ntm                          7.816179e+01
# maximum_nights_avg_ntm                          3.998608e+07
# availability_30                                 4.467838e+01
# availability_60                                 9.625608e+01
# availability_90                                 1.493755e+02
# availability_365                                6.085428e+02
# number_of_reviews                               2.900876e+02
# number_of_reviews_ltm                           8.118840e+01
# number_of_reviews_l30d                          6.989511e+00
# number_of_reviews_ly                            7.955469e+01
# estimated_occupancy_l365d                       3.517942e+02
# estimated_revenue_l365d                         9.278317e+03
# review_scores_rating                            8.990597e+00
# review_scores_accuracy                          9.046916e+00
# review_scores_cleanliness                       8.996061e+00
# review_scores_checkin                           9.120433e+00
# review_scores_communication                     9.112752e+00
# review_scores_location                          9.111670e+00
# review_scores_value                             8.932726e+00
# calculated_host_listings_count                  1.241834e+02
# calculated_host_listings_count_entire_homes     1.200090e+02
# calculated_host_listings_count_private_rooms    2.471304e+01
# dtype: float64
# Limite inferior permitido host_response_rate                             -2.977152e+01
# host_acceptance_rate                            1.937495e+01
# latitude                                        1.927770e+01
# longitude                                      -9.926651e+01
# accommodates                                   -3.730348e+00
# bathrooms                                      -1.822087e+00
# bedrooms                                       -2.307458e+00
# beds                                           -3.138824e+00
# price                                          -1.048770e+04
# minimum_nights                                 -7.047998e+01
# maximum_nights                                 -7.303947e+02
# minimum_minimum_nights                         -6.898984e+01
# maximum_minimum_nights                         -6.972673e+01
# minimum_maximum_nights                         -3.981991e+07
# maximum_maximum_nights                         -3.981989e+07
# minimum_nights_avg_ntm                         -6.905486e+01
# maximum_nights_avg_ntm                         -3.981990e+07
# availability_30                                -1.906408e+01
# availability_60                                -3.096034e+01
# availability_90                                -4.005235e+01
# availability_365                               -1.719011e+02
# number_of_reviews                              -1.891181e+02
# number_of_reviews_ltm                          -5.084191e+01
# number_of_reviews_l30d                         -4.547419e+00
# number_of_reviews_ly                           -5.052573e+01
# estimated_occupancy_l365d                      -1.867360e+02
# estimated_revenue_l365d                        -6.767906e+03
# review_scores_rating                           -6.784725e-01
# review_scores_accuracy                         -6.770603e-01
# review_scores_cleanliness                      -6.780044e-01
# review_scores_checkin                          -6.565452e-01
# review_scores_communication                    -6.738350e-01
# review_scores_location                         -6.424519e-01
# review_scores_value                            -6.846565e-01
# calculated_host_listings_count                 -9.319963e+01
# calculated_host_listings_count_entire_homes    -9.476373e+01
# calculated_host_listings_count_private_rooms   -1.933291e+01
# dtype: float64

# %%
# Outliers se convierten en nulos 
data3= cuantitativas[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
#        host_response_rate  host_acceptance_rate   latitude  longitude  \
# 0                       0                  99.0  19.382830        NaN
# 1                     100                  90.0  19.411620 -99.177940
# 2                      88                 100.0  19.439770 -99.156050
# 3                     100                  47.0  19.411520 -99.168570
# 4                     100                  93.0  19.354480 -99.162170
# ...                   ...                   ...        ...        ...
# 26062                  90                  99.0  19.430390 -99.134282
# 26063                  80                  99.0  19.439520 -99.152520
# 26064                 100                  85.0  19.417618 -99.166841
# 26065                 100                 100.0  19.428857 -99.177626
# 26066                   0                  99.0  19.416223 -99.156934
#
#        accommodates  bathrooms  bedrooms  beds        price  minimum_nights  \
# 0               2.0        1.0       1.0   1.0  3982.000000             1.0
# 1               NaN        NaN       5.0   1.0  9590.923077             1.0
# 2               2.0        1.0       1.0   1.0   585.000000            15.0
# 3               4.0        1.0       2.0   1.0  1361.084154             2.0
# 4               2.0        1.0       1.0   1.0  1015.000000             3.0
# ...             ...        ...       ...   ...          ...             ...
# 26062           4.0        1.0       1.0   4.0   529.000000             1.0
# 26063           2.0        1.0       1.0   1.0   472.000000             1.0
# 26064           1.0        1.0       1.0   1.0   399.000000             1.0
# 26065           2.0        1.0       1.0   1.0  1494.000000             1.0
# 26066           6.0        2.0       2.0   2.0  1722.000000             3.0
#
#        ...  review_scores_rating  review_scores_accuracy  \
# 0      ...                  0.00                    0.00
# 1      ...                  4.59                    4.56
# 2      ...                  4.87                    4.95
# 3      ...                  4.90                    4.82
# 4      ...                  4.92                    4.91
# ...    ...                   ...                     ...
# 26062  ...                  0.00                    0.00
# 26063  ...                  0.00                    0.00
# 26064  ...                  0.00                    0.00
# 26065  ...                  0.00                    0.00
# 26066  ...                  0.00                    0.00
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           0.00                   0.00
# 1                           4.70                   4.87
# 2                           4.88                   4.98
# 3                           4.76                   4.94
# 4                           4.96                   4.96
# ...                          ...                    ...
# 26062                       0.00                   0.00
# 26063                       0.00                   0.00
# 26064                       0.00                   0.00
# 26065                       0.00                   0.00
# 26066                       0.00                   0.00
#
#        review_scores_communication  review_scores_location  \
# 0                             0.00                    0.00
# 1                             4.78                    4.98
# 2                             4.94                    4.76
# 3                             4.92                    4.98
# 4                             4.98                    4.96
# ...                            ...                     ...
# 26062                         0.00                    0.00
# 26063                         0.00                    0.00
# 26064                         0.00                    0.00
# 26065                         0.00                    0.00
# 26066                         0.00                    0.00
#
#        review_scores_value  calculated_host_listings_count  \
# 0                     0.00                             1.0
# 1                     4.47                             9.0
# 2                     4.79                             1.0
# 3                     4.92                             2.0
# 4                     4.92                             3.0
# ...                    ...                             ...
# 26062                 0.00                             8.0
# 26063                 0.00                             1.0
# 26064                 0.00                             2.0
# 26065                 0.00                            32.0
# 26066                 0.00                             1.0
#
#        calculated_host_listings_count_entire_homes  \
# 0                                              1.0
# 1                                              4.0
# 2                                              1.0
# 3                                              2.0
# 4                                              2.0
# ...                                            ...
# 26062                                          0.0
# 26063                                          0.0
# 26064                                          0.0
# 26065                                         32.0
# 26066                                          1.0
#
#        calculated_host_listings_count_private_rooms
# 0                                               0.0
# 1                                               2.0
# 2                                               0.0
# 3                                               0.0
# 4                                               1.0
# ...                                             ...
# 26062                                           4.0
# 26063                                           1.0
# 26064                                           2.0
# 26065                                           0.0
# 26066                                           0.0
#
# [26067 rows x 37 columns]

# %%
data_clean=data3.copy()
data_clean=data_clean.fillna(round(data3.mean(),1))
data_clean
# Out:
#        host_response_rate  host_acceptance_rate   latitude  longitude  \
# 0                       0                  99.0  19.382830 -99.200000
# 1                     100                  90.0  19.411620 -99.177940
# 2                      88                 100.0  19.439770 -99.156050
# 3                     100                  47.0  19.411520 -99.168570
# 4                     100                  93.0  19.354480 -99.162170
# ...                   ...                   ...        ...        ...
# 26062                  90                  99.0  19.430390 -99.134282
# 26063                  80                  99.0  19.439520 -99.152520
# 26064                 100                  85.0  19.417618 -99.166841
# 26065                 100                 100.0  19.428857 -99.177626
# 26066                   0                  99.0  19.416223 -99.156934
#
#        accommodates  bathrooms  bedrooms  beds        price  minimum_nights  \
# 0               2.0        1.0       1.0   1.0  3982.000000             1.0
# 1               3.1        1.4       5.0   1.0  9590.923077             1.0
# 2               2.0        1.0       1.0   1.0   585.000000            15.0
# 3               4.0        1.0       2.0   1.0  1361.084154             2.0
# 4               2.0        1.0       1.0   1.0  1015.000000             3.0
# ...             ...        ...       ...   ...          ...             ...
# 26062           4.0        1.0       1.0   4.0   529.000000             1.0
# 26063           2.0        1.0       1.0   1.0   472.000000             1.0
# 26064           1.0        1.0       1.0   1.0   399.000000             1.0
# 26065           2.0        1.0       1.0   1.0  1494.000000             1.0
# 26066           6.0        2.0       2.0   2.0  1722.000000             3.0
#
#        ...  review_scores_rating  review_scores_accuracy  \
# 0      ...                  0.00                    0.00
# 1      ...                  4.59                    4.56
# 2      ...                  4.87                    4.95
# 3      ...                  4.90                    4.82
# 4      ...                  4.92                    4.91
# ...    ...                   ...                     ...
# 26062  ...                  0.00                    0.00
# 26063  ...                  0.00                    0.00
# 26064  ...                  0.00                    0.00
# 26065  ...                  0.00                    0.00
# 26066  ...                  0.00                    0.00
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           0.00                   0.00
# 1                           4.70                   4.87
# 2                           4.88                   4.98
# 3                           4.76                   4.94
# 4                           4.96                   4.96
# ...                          ...                    ...
# 26062                       0.00                   0.00
# 26063                       0.00                   0.00
# 26064                       0.00                   0.00
# 26065                       0.00                   0.00
# 26066                       0.00                   0.00
#
#        review_scores_communication  review_scores_location  \
# 0                             0.00                    0.00
# 1                             4.78                    4.98
# 2                             4.94                    4.76
# 3                             4.92                    4.98
# 4                             4.98                    4.96
# ...                            ...                     ...
# 26062                         0.00                    0.00
# 26063                         0.00                    0.00
# 26064                         0.00                    0.00
# 26065                         0.00                    0.00
# 26066                         0.00                    0.00
#
#        review_scores_value  calculated_host_listings_count  \
# 0                     0.00                             1.0
# 1                     4.47                             9.0
# 2                     4.79                             1.0
# 3                     4.92                             2.0
# 4                     4.92                             3.0
# ...                    ...                             ...
# 26062                 0.00                             8.0
# 26063                 0.00                             1.0
# 26064                 0.00                             2.0
# 26065                 0.00                            32.0
# 26066                 0.00                             1.0
#
#        calculated_host_listings_count_entire_homes  \
# 0                                              1.0
# 1                                              4.0
# 2                                              1.0
# 3                                              2.0
# 4                                              2.0
# ...                                            ...
# 26062                                          0.0
# 26063                                          0.0
# 26064                                          0.0
# 26065                                         32.0
# 26066                                          1.0
#
#        calculated_host_listings_count_private_rooms
# 0                                               0.0
# 1                                               2.0
# 2                                               0.0
# 3                                               0.0
# 4                                               1.0
# ...                                             ...
# 26062                                           4.0
# 26063                                           1.0
# 26064                                           2.0
# 26065                                           0.0
# 26066                                           0.0
#
# [26067 rows x 37 columns]

# %%
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# host_response_rate                              0
# host_acceptance_rate                            0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# availability_30                                 0
# availability_60                                 0
# availability_90                                 0
# availability_365                                0
# number_of_reviews                               0
# number_of_reviews_ltm                           0
# number_of_reviews_l30d                          0
# number_of_reviews_ly                            0
# estimated_occupancy_l365d                       0
# estimated_revenue_l365d                         0
# review_scores_rating                            0
# review_scores_accuracy                          0
# review_scores_cleanliness                       0
# review_scores_checkin                           0
# review_scores_communication                     0
# review_scores_location                          0
# review_scores_value                             0
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# dtype: int64

# %%
data_clean.to_csv("MexicoCity_Sin_Atipicos_Desv.csv")

# %% [markdown]
# Procedimiento de cuantiles

# %%
fig = plt.figure(figsize =(15, 8))
cuantitativas.plot(kind='box', vert=False)
#cuantitativas['subtotal_ventas_alimentos_bebidas'].plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
#Dividir cuartiles
y=cuantitativas

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido host_response_rate                               109.000000
# host_acceptance_rate                             106.000000
# latitude                                          19.492090
# longitude                                        -99.117639
# accommodates                                       7.000000
# bathrooms                                          3.500000
# bedrooms                                           3.500000
# beds                                               3.500000
# price                                           3287.000000
# minimum_nights                                     3.500000
# maximum_nights                                  2542.500000
# minimum_minimum_nights                             3.500000
# maximum_minimum_nights                             6.000000
# minimum_maximum_nights                          2265.000000
# maximum_maximum_nights                          2265.000000
# minimum_nights_avg_ntm                             5.000000
# maximum_nights_avg_ntm                          2265.000000
# availability_30                                   52.000000
# availability_60                                  109.000000
# availability_90                                  156.000000
# availability_365                                 725.500000
# number_of_reviews                                154.000000
# number_of_reviews_ltm                             57.500000
# number_of_reviews_l30d                             5.000000
# number_of_reviews_ly                              55.000000
# estimated_occupancy_l365d                        360.000000
# estimated_revenue_l365d                         3990.000000
# review_scores_rating                               5.470000
# review_scores_accuracy                             5.430000
# review_scores_cleanliness                          5.510000
# review_scores_checkin                              5.370000
# review_scores_communication                        5.440000
# review_scores_location                             5.425000
# review_scores_value                                5.500000
# calculated_host_listings_count                    26.000000
# calculated_host_listings_count_entire_homes       15.000000
# calculated_host_listings_count_private_rooms       5.000000
# dtype: float64
# Limite inferior permitido host_response_rate                                85.000000
# host_acceptance_rate                              90.000000
# latitude                                          19.331690
# longitude                                        -99.215613
# accommodates                                      -1.000000
# bathrooms                                         -0.500000
# bedrooms                                          -0.500000
# beds                                              -0.500000
# price                                           -857.000000
# minimum_nights                                    -0.500000
# maximum_nights                                 -1237.500000
# minimum_minimum_nights                            -0.500000
# maximum_minimum_nights                            -2.000000
# minimum_maximum_nights                          -775.000000
# maximum_maximum_nights                          -775.000000
# minimum_nights_avg_ntm                            -1.400000
# maximum_nights_avg_ntm                          -775.000000
# availability_30                                  -28.000000
# availability_60                                  -43.000000
# availability_90                                  -44.000000
# availability_365                                -294.500000
# number_of_reviews                                -86.000000
# number_of_reviews_ltm                            -34.500000
# number_of_reviews_l30d                            -3.000000
# number_of_reviews_ly                             -33.000000
# estimated_occupancy_l365d                       -216.000000
# estimated_revenue_l365d                        -2394.000000
# review_scores_rating                               4.030000
# review_scores_accuracy                             4.150000
# review_scores_cleanliness                          3.990000
# review_scores_checkin                              4.330000
# review_scores_communication                        4.240000
# review_scores_location                             4.265000
# review_scores_value                                3.900000
# calculated_host_listings_count                   -14.000000
# calculated_host_listings_count_entire_homes       -9.000000
# calculated_host_listings_count_private_rooms      -3.000000
# dtype: float64

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= cuantitativas[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
#        host_response_rate  host_acceptance_rate   latitude  longitude  \
# 0                     NaN                  99.0  19.382830        NaN
# 1                   100.0                  90.0  19.411620 -99.177940
# 2                    88.0                 100.0  19.439770 -99.156050
# 3                   100.0                   NaN  19.411520 -99.168570
# 4                   100.0                  93.0  19.354480 -99.162170
# ...                   ...                   ...        ...        ...
# 26062                90.0                  99.0  19.430390 -99.134282
# 26063                 NaN                  99.0  19.439520 -99.152520
# 26064               100.0                   NaN  19.417618 -99.166841
# 26065               100.0                 100.0  19.428857 -99.177626
# 26066                 NaN                  99.0  19.416223 -99.156934
#
#        accommodates  bathrooms  bedrooms  beds        price  minimum_nights  \
# 0               2.0        1.0       1.0   1.0          NaN             1.0
# 1               NaN        NaN       NaN   1.0          NaN             1.0
# 2               2.0        1.0       1.0   1.0   585.000000             NaN
# 3               4.0        1.0       2.0   1.0  1361.084154             2.0
# 4               2.0        1.0       1.0   1.0  1015.000000             3.0
# ...             ...        ...       ...   ...          ...             ...
# 26062           4.0        1.0       1.0   NaN   529.000000             1.0
# 26063           2.0        1.0       1.0   1.0   472.000000             1.0
# 26064           1.0        1.0       1.0   1.0   399.000000             1.0
# 26065           2.0        1.0       1.0   1.0  1494.000000             1.0
# 26066           6.0        2.0       2.0   2.0  1722.000000             3.0
#
#        ...  review_scores_rating  review_scores_accuracy  \
# 0      ...                   NaN                     NaN
# 1      ...                  4.59                    4.56
# 2      ...                  4.87                    4.95
# 3      ...                  4.90                    4.82
# 4      ...                  4.92                    4.91
# ...    ...                   ...                     ...
# 26062  ...                   NaN                     NaN
# 26063  ...                   NaN                     NaN
# 26064  ...                   NaN                     NaN
# 26065  ...                   NaN                     NaN
# 26066  ...                   NaN                     NaN
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                            NaN                    NaN
# 1                           4.70                   4.87
# 2                           4.88                   4.98
# 3                           4.76                   4.94
# 4                           4.96                   4.96
# ...                          ...                    ...
# 26062                        NaN                    NaN
# 26063                        NaN                    NaN
# 26064                        NaN                    NaN
# 26065                        NaN                    NaN
# 26066                        NaN                    NaN
#
#        review_scores_communication  review_scores_location  \
# 0                              NaN                     NaN
# 1                             4.78                    4.98
# 2                             4.94                    4.76
# 3                             4.92                    4.98
# 4                             4.98                    4.96
# ...                            ...                     ...
# 26062                          NaN                     NaN
# 26063                          NaN                     NaN
# 26064                          NaN                     NaN
# 26065                          NaN                     NaN
# 26066                          NaN                     NaN
#
#        review_scores_value  calculated_host_listings_count  \
# 0                      NaN                             1.0
# 1                     4.47                             9.0
# 2                     4.79                             1.0
# 3                     4.92                             2.0
# 4                     4.92                             3.0
# ...                    ...                             ...
# 26062                  NaN                             8.0
# 26063                  NaN                             1.0
# 26064                  NaN                             2.0
# 26065                  NaN                             NaN
# 26066                  NaN                             1.0
#
#        calculated_host_listings_count_entire_homes  \
# 0                                              1.0
# 1                                              4.0
# 2                                              1.0
# 3                                              2.0
# 4                                              2.0
# ...                                            ...
# 26062                                          0.0
# 26063                                          0.0
# 26064                                          0.0
# 26065                                          NaN
# 26066                                          1.0
#
#        calculated_host_listings_count_private_rooms
# 0                                               0.0
# 1                                               2.0
# 2                                               0.0
# 3                                               0.0
# 4                                               1.0
# ...                                             ...
# 26062                                           4.0
# 26063                                           1.0
# 26064                                           2.0
# 26065                                           0.0
# 26066                                           0.0
#
# [26067 rows x 37 columns]

# %%
valores_nulos=data3_iqr.isnull().sum()
valores_nulos
# Out:
# host_response_rate                              5517
# host_acceptance_rate                            4798
# latitude                                        1802
# longitude                                       2885
# accommodates                                    1302
# bathrooms                                        693
# bedrooms                                         846
# beds                                            2212
# price                                           2051
# minimum_nights                                  3489
# maximum_nights                                     0
# minimum_minimum_nights                          3014
# maximum_minimum_nights                          1914
# minimum_maximum_nights                             1
# maximum_maximum_nights                            13
# minimum_nights_avg_ntm                          1964
# maximum_nights_avg_ntm                            12
# availability_30                                    0
# availability_60                                    0
# availability_90                                    0
# availability_365                                   0
# number_of_reviews                               2147
# number_of_reviews_ltm                           1103
# number_of_reviews_l30d                           877
# number_of_reviews_ly                            1224
# estimated_occupancy_l365d                          0
# estimated_revenue_l365d                         1802
# review_scores_rating                            4254
# review_scores_accuracy                          4206
# review_scores_cleanliness                       3817
# review_scores_checkin                           4104
# review_scores_communication                     4177
# review_scores_location                          3972
# review_scores_value                             3889
# calculated_host_listings_count                  3320
# calculated_host_listings_count_entire_homes     3795
# calculated_host_listings_count_private_rooms    3254
# dtype: int64

# %%
data4_iqr=data3_iqr.copy()
data4_iqr=data4_iqr.fillna(round(data3_iqr.median(),1))
data4_iqr
# Out:
#        host_response_rate  host_acceptance_rate   latitude  longitude  \
# 0                   100.0                  99.0  19.382830 -99.200000
# 1                   100.0                  90.0  19.411620 -99.177940
# 2                    88.0                 100.0  19.439770 -99.156050
# 3                   100.0                 100.0  19.411520 -99.168570
# 4                   100.0                  93.0  19.354480 -99.162170
# ...                   ...                   ...        ...        ...
# 26062                90.0                  99.0  19.430390 -99.134282
# 26063               100.0                  99.0  19.439520 -99.152520
# 26064               100.0                 100.0  19.417618 -99.166841
# 26065               100.0                 100.0  19.428857 -99.177626
# 26066               100.0                  99.0  19.416223 -99.156934
#
#        accommodates  bathrooms  bedrooms  beds        price  minimum_nights  \
# 0               2.0        1.0       1.0   1.0   999.000000             1.0
# 1               2.0        1.0       1.0   1.0   999.000000             1.0
# 2               2.0        1.0       1.0   1.0   585.000000             1.0
# 3               4.0        1.0       2.0   1.0  1361.084154             2.0
# 4               2.0        1.0       1.0   1.0  1015.000000             3.0
# ...             ...        ...       ...   ...          ...             ...
# 26062           4.0        1.0       1.0   1.0   529.000000             1.0
# 26063           2.0        1.0       1.0   1.0   472.000000             1.0
# 26064           1.0        1.0       1.0   1.0   399.000000             1.0
# 26065           2.0        1.0       1.0   1.0  1494.000000             1.0
# 26066           6.0        2.0       2.0   2.0  1722.000000             3.0
#
#        ...  review_scores_rating  review_scores_accuracy  \
# 0      ...                  4.80                    4.90
# 1      ...                  4.59                    4.56
# 2      ...                  4.87                    4.95
# 3      ...                  4.90                    4.82
# 4      ...                  4.92                    4.91
# ...    ...                   ...                     ...
# 26062  ...                  4.80                    4.90
# 26063  ...                  4.80                    4.90
# 26064  ...                  4.80                    4.90
# 26065  ...                  4.80                    4.90
# 26066  ...                  4.80                    4.90
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.90                   4.90
# 1                           4.70                   4.87
# 2                           4.88                   4.98
# 3                           4.76                   4.94
# 4                           4.96                   4.96
# ...                          ...                    ...
# 26062                       4.90                   4.90
# 26063                       4.90                   4.90
# 26064                       4.90                   4.90
# 26065                       4.90                   4.90
# 26066                       4.90                   4.90
#
#        review_scores_communication  review_scores_location  \
# 0                             4.90                    4.90
# 1                             4.78                    4.98
# 2                             4.94                    4.76
# 3                             4.92                    4.98
# 4                             4.98                    4.96
# ...                            ...                     ...
# 26062                         4.90                    4.90
# 26063                         4.90                    4.90
# 26064                         4.90                    4.90
# 26065                         4.90                    4.90
# 26066                         4.90                    4.90
#
#        review_scores_value  calculated_host_listings_count  \
# 0                     4.80                             1.0
# 1                     4.47                             9.0
# 2                     4.79                             1.0
# 3                     4.92                             2.0
# 4                     4.92                             3.0
# ...                    ...                             ...
# 26062                 4.80                             8.0
# 26063                 4.80                             1.0
# 26064                 4.80                             2.0
# 26065                 4.80                             2.0
# 26066                 4.80                             1.0
#
#        calculated_host_listings_count_entire_homes  \
# 0                                              1.0
# 1                                              4.0
# 2                                              1.0
# 3                                              2.0
# 4                                              2.0
# ...                                            ...
# 26062                                          0.0
# 26063                                          0.0
# 26064                                          0.0
# 26065                                          1.0
# 26066                                          1.0
#
#        calculated_host_listings_count_private_rooms
# 0                                               0.0
# 1                                               2.0
# 2                                               0.0
# 3                                               0.0
# 4                                               1.0
# ...                                             ...
# 26062                                           4.0
# 26063                                           1.0
# 26064                                           2.0
# 26065                                           0.0
# 26066                                           0.0
#
# [26067 rows x 37 columns]

# %%
Datos_limpios = pd.concat([cualitativas, data4_iqr], axis=1)
Datos_limpios
# Out:
#        host_response_time  host_response_rate host_is_superhost  \
# 0                 Unknown                   0                 f
# 1      within a few hours                 100                 f
# 2            within a day                  88                 f
# 3          within an hour                 100                 t
# 4      within a few hours                 100                 t
# ...                   ...                 ...               ...
# 26062      within an hour                  90                 f
# 26063      within an hour                  80                 f
# 26064      within an hour                 100                 t
# 26065      within an hour                 100                 t
# 26066             Unknown                   0                 f
#
#              host_location host_has_profile_pic host_identity_verified  \
# 0      Mexico City, Mexico                    t                      t
# 1      Mexico City, Mexico                    t                      t
# 2      Mexico City, Mexico                    t                      t
# 3      Mexico City, Mexico                    t                      t
# 4      Mexico City, Mexico                    t                      t
# ...                    ...                  ...                    ...
# 26062              Unknown                    t                      t
# 26063  Mexico City, Mexico                    t                      t
# 26064  Mexico City, Mexico                    t                      t
# 26065  Mexico City, Mexico                    t                      t
# 26066              Unknown                    t                      f
#
#       neighbourhood_cleansed                property_type        room_type  \
# 0      Cuajimalpa de Morelos                 Entire villa  Entire home/apt
# 1                 Cuauhtémoc                  Entire home  Entire home/apt
# 2                 Cuauhtémoc                 Entire condo  Entire home/apt
# 3                 Cuauhtémoc           Entire rental unit  Entire home/apt
# 4                   Coyoacán           Entire rental unit  Entire home/apt
# ...                      ...                          ...              ...
# 26062             Cuauhtémoc         Shared room in hotel      Shared room
# 26063             Cuauhtémoc         Private room in loft     Private room
# 26064             Cuauhtémoc  Private room in rental unit     Private room
# 26065         Miguel Hidalgo           Entire rental unit  Entire home/apt
# 26066             Cuauhtémoc           Entire rental unit  Entire home/apt
#
#                                                amenities  ...  \
# 0      ["Wifi", "Garden view", "Pocket wifi", "Free p...  ...
# 1      ["Hair dryer", "Hangers", "Microwave", "Cookin...  ...
# 2      ["Wine glasses", "Hangers", "Cooking basics", ...  ...
# 3      ["Hangers", "Extra pillows and blankets", "Wif...  ...
# 4      ["Wine glasses", "Portable heater", "Private e...  ...
# ...                                                  ...  ...
# 26062  ["Fire extinguisher", "Carbon monoxide alarm",...  ...
# 26063  ["Hangers", "Cooking basics", "Microwave", "Ex...  ...
# 26064  ["Wifi", "Fire extinguisher", "Kitchen", "Carb...  ...
# 26065  ["Wine glasses", "Hair dryer", "Hangers", "Cen...  ...
# 26066  ["Wine glasses", "Hangers", "Cooking basics", ...  ...
#
#       review_scores_rating review_scores_accuracy  review_scores_cleanliness  \
# 0                     4.80                   4.90                       4.90
# 1                     4.59                   4.56                       4.70
# 2                     4.87                   4.95                       4.88
# 3                     4.90                   4.82                       4.76
# 4                     4.92                   4.91                       4.96
# ...                    ...                    ...                        ...
# 26062                 4.80                   4.90                       4.90
# 26063                 4.80                   4.90                       4.90
# 26064                 4.80                   4.90                       4.90
# 26065                 4.80                   4.90                       4.90
# 26066                 4.80                   4.90                       4.90
#
#        review_scores_checkin  review_scores_communication  \
# 0                       4.90                         4.90
# 1                       4.87                         4.78
# 2                       4.98                         4.94
# 3                       4.94                         4.92
# 4                       4.96                         4.98
# ...                      ...                          ...
# 26062                   4.90                         4.90
# 26063                   4.90                         4.90
# 26064                   4.90                         4.90
# 26065                   4.90                         4.90
# 26066                   4.90                         4.90
#
#        review_scores_location  review_scores_value  \
# 0                        4.90                 4.80
# 1                        4.98                 4.47
# 2                        4.76                 4.79
# 3                        4.98                 4.92
# 4                        4.96                 4.92
# ...                       ...                  ...
# 26062                    4.90                 4.80
# 26063                    4.90                 4.80
# 26064                    4.90                 4.80
# 26065                    4.90                 4.80
# 26066                    4.90                 4.80
#
#        calculated_host_listings_count  \
# 0                                 1.0
# 1                                 9.0
# 2                                 1.0
# 3                                 2.0
# 4                                 3.0
# ...                               ...
# 26062                             8.0
# 26063                             1.0
# 26064                             2.0
# 26065                             2.0
# 26066                             1.0
#
#        calculated_host_listings_count_entire_homes  \
# 0                                              1.0
# 1                                              4.0
# 2                                              1.0
# 3                                              2.0
# 4                                              2.0
# ...                                            ...
# 26062                                          0.0
# 26063                                          0.0
# 26064                                          0.0
# 26065                                          1.0
# 26066                                          1.0
#
#        calculated_host_listings_count_private_rooms
# 0                                               0.0
# 1                                               2.0
# 2                                               0.0
# 3                                               0.0
# 4                                               1.0
# ...                                             ...
# 26062                                           4.0
# 26063                                           1.0
# 26064                                           2.0
# 26065                                           0.0
# 26066                                           0.0
#
# [26067 rows x 49 columns]

# %%
valores_nulos=Datos_limpios.isnull().sum()
valores_nulos
# Out:
# host_response_time                              0
# host_response_rate                              0
# host_is_superhost                               0
# host_location                                   0
# host_has_profile_pic                            0
# host_identity_verified                          0
# neighbourhood_cleansed                          0
# property_type                                   0
# room_type                                       0
# amenities                                       0
# has_availability                                0
# instant_bookable                                0
# host_response_rate                              0
# host_acceptance_rate                            0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# availability_30                                 0
# availability_60                                 0
# availability_90                                 0
# availability_365                                0
# number_of_reviews                               0
# number_of_reviews_ltm                           0
# number_of_reviews_l30d                          0
# number_of_reviews_ly                            0
# estimated_occupancy_l365d                       0
# estimated_revenue_l365d                         0
# review_scores_rating                            0
# review_scores_accuracy                          0
# review_scores_cleanliness                       0
# review_scores_checkin                           0
# review_scores_communication                     0
# review_scores_location                          0
# review_scores_value                             0
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# dtype: int64

# %%
Datos_limpios.to_csv("MexicoCity_Sin_Atipicos.csv")
